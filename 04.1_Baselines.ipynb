# %% [markdown]
# # Pre entrenamiento

# %%
import pandas as pd
import numpy as np
import datetime
from pandas_summary import DataFrameSummary

# %%
df = pd.read_feather('train_normalized_data.fth')
df_test = pd.read_feather('test_normalized_data.fth')

# %%
df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]
len(df_train)/len(df), len(df_val)/len(df), len(df), len(df_val)
# Out:
# (0.9642465458145908, 0.035753454185409164, 844338, 30188)

# %% [markdown]
# Es importante separar por fechas para poder validar con datos que yo haya usado para entrenar el problema.

# %%
final_train = False

# %%
def get_metric(sales, sales_):
    return np.sqrt((((sales - sales_)/sales)**2).sum()/len(sales))

# %% [markdown]
# $\textrm{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^{n} \left(\frac{\hat{y}_i - y_i}{y_i}\right)^2}$

# %%
df_train.columns
# Out:
# Index(['index', 'Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Week',
#        'Day', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval',
#        'CompetitionOpenSince', 'Promo2Since', 'State', 'file', 'week', 'trend',
#        'Date_y', 'Month_y', 'Day_y', 'file_DE', 'week_DE', 'trend_DE',
#        'Date_DE', 'State_DE', 'Month_DE', 'Day_DE', 'file_y',
#        'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
#        'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC', 'Max_Humidity',
#        'Mean_Humidity', 'Min_Humidity', 'Max_Sea_Level_PressurehPa',
#        'Mean_Sea_Level_PressurehPa', 'Min_Sea_Level_PressurehPa',
#        'Max_VisibilityKm', 'Mean_VisibilityKm', 'Min_VisibilitykM',
#        'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h', 'Max_Gust_SpeedKm_h',
#        'Precipitationmm', 'CloudCover', 'Events', 'WindDirDegrees',
#        'StateName', 'Year_y', 'Week_y', 'CompetitionDaysOpen',
#        'CompetitionMonthsOpen', 'Promo2Days', 'Promo2Weeks',
#        'StateHoliday_bool', 'AfterSchoolHoliday', 'BeforeSchoolHoliday',
#        'AfterStateHoliday_bool', 'BeforeStateHoliday_bool', 'AfterPromo',
#        'BeforePromo', 'SchoolHoliday_bw', 'StateHoliday_bool_bw', 'Promo_bw',
#        'SchoolHoliday_fw', 'StateHoliday_bool_fw', 'Promo_fw'],
#       dtype='object')

# %%
df_train['Events']
# Out:
# 30188     20
# 30189     20
# 30190      0
# 30191     20
# 30192     20
#           ..
# 844333    10
# 844334    10
# 844335    10
# 844336     1
# 844337    10
# Name: Events, Length: 814150, dtype: int64

# %% [markdown]
# normalizo diviendo por el maximo

# %%
max_sales = df_train['Sales'].max()
df.loc[:, 'Sales_norm'] = df['Sales'].values/max_sales

# %%
df_train.loc[:, 'Sales_norm'] = df_train['Sales'].values/max_sales
df_val.loc[:, 'Sales_norm'] = df_val['Sales'].values/max_sales
# Out:
# C:\Users\pazar\AppData\Local\Temp\ipykernel_2208\2193462401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.loc[:, 'Sales_norm'] = df_train['Sales'].values/max_sales
# C:\Users\pazar\AppData\Local\Temp\ipykernel_2208\2193462401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val.loc[:, 'Sales_norm'] = df_val['Sales'].values/max_sales

# %%
print('Train:')
print(get_metric(df_train['Sales_norm'], 
                 df_train['Sales_norm'].mean()))
print('Val:')
get_metric(df_val['Sales_norm'], 
           df_train['Sales_norm'].mean())
# Out:
# Train:
# 0.6371089378658743
# Val:
# 0.5496723521813329

# %%
def get_mean_by_column(column, sales_str):
    group_means_dict = {}
    group_mean_list = []
    for col_value, group_df in df_train.groupby(column):
        group_mean =  group_df[group_df[sales_str] > 0][sales_str].mean()
        group_means_dict[col_value] = group_mean
        group_mean_list.append(group_mean)
    print('Train:', get_metric(df_train[sales_str], 
                               df_train[column].apply(group_means_dict.get)))
    print('Val:', get_metric(df_val[sales_str], 
                             df_val[column].apply(group_means_dict.get)))
    return group_means_dict, group_mean_list

# %%
# Media por store
_ = get_mean_by_column('Store', 'Sales_norm')
# Out:
# Train: 0.3960913521241833
# Val: 0.3071746085338872

# %% [markdown]
# que el baseline sea la media del store es lo mas sensato :)

# %%
# Media por dia de la semana
_ = get_mean_by_column('DayOfWeek', 'Sales_norm')
# Out:
# Train: 0.6008874922754364
# Val: 0.5061392186635405

# %%
# Media por numera de semana (1-52)
_ = get_mean_by_column('Week', 'Sales_norm')
# Out:
# Train: 0.6077405789213655
# Val: 0.5171468581189804

# %%
_ = get_mean_by_column('Month', 'Sales_norm')
# Out:
# Train: 0.6326710739722268
# Val: 0.544465040070309

# %%
_ = get_mean_by_column('StateHoliday', 'Sales_norm')
# Out:
# Train: 0.6379671046048598
# Val: 0.5494193814701794

# %%
_ = get_mean_by_column('SchoolHoliday', 'Sales_norm')
# Out:
# Train: 0.6352131730794401
# Val: 0.5522886254888293

# %% [markdown]
# # Red Neuronal

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import callbacks

# %%
def rmspe(y_true, y_pred):
    return K.sqrt(K.mean(K.square((y_true - y_pred)/y_true)))

# %%
def get_keras_LR(X_columns, hidden_units=1):
    inputs = []
    activation = 'linear'
    if hidden_units>1:
        activation = 'relu'
    for i, col in enumerate(X_columns):
        inp = Input(shape=(X_train[i].shape[1],), name=f"{col}_input")
        inputs.append(inp)
    if len(X_columns)>1:
        concat_out = Concatenate()(inputs)
        dense_out = Dense(hidden_units, name='Dense', activation=activation)(concat_out)
    else:
        dense_out = Dense(hidden_units, name='Dense', activation=activation)(inputs[0])
    if hidden_units>1:
        dense_out = Dense(1, name='Dense_out')(dense_out)
    model = Model(inputs, dense_out)
    model.compile(optimizers.Adam(learning_rate=0.001), loss='mse', metrics=[rmspe, 'mse'])
    return model


def get_embedings_NN(X_columns, hidden_units = 32, activation = 'relu'):
    embed_outs = []
    inputs = []
    for i, col in enumerate(X_columns):
        inp = Input(shape=(1,), name=f"{col}_input")
        inputs.append(inp)
        if col in embed_outs_dict:
            embed_out = Embedding(len(np.unique(X_train[i])), embed_outs_dict[col], name=f"{col}_embedding", mask_zero=False)(inp)
            out = Flatten(name=f"{col}_flatten")(embed_out)
            embed_outs.append(out)
        else:
            embed_outs.append(inp)
        
    if len(X_columns)>1:
        concat_out = Concatenate()(embed_outs)
        dense_out = Dense(hidden_units, activation=activation)(concat_out)
    else:
        dense_out = Dense(hidden_units, activation=activation)(out)
    out = Dense(1)(dense_out)
    model = Model(inputs, out)
    model.compile(optimizers.Adam(learning_rate=0.001), loss='mse', metrics=[rmspe, 'mse'])
    return model

# %%
with_embed = True

embed_outs_dict = {'Store': 2, 'DayOfWeek': 2, 'Promo': 5, 'Year': 2, 'Month': 2, 'Week': 2, 'Day': 2, 
                   'StoreType': 3, 'Assortment': 3, 'CompetitionDistance': 5, 'Promo2': 3,'PromoInterval': 2,
                    'trend': 2, 'Precipitationmm': 2, 'Mean_TemperatureC':2, 'CloudCover':2, 'Events':2}

X_columns = list(embed_outs_dict.keys())# + ['BeforeStateHoliday_bool', 'Max_TemperatureC'] # ['Precipitationmm']

if final_train:
    X_train = np.hsplit(df[X_columns].values, len(X_columns))
    y_train = df['Sales_norm']
else:
    X_train = np.hsplit(df_train[X_columns].values, len(X_columns))
    y_train = df_train['Sales_norm']
    
X_val = np.hsplit(df_val[X_columns].values, len(X_columns))
X_test = np.hsplit(df_test[X_columns].values, len(X_columns))

if not with_embed:
    for i in range(len(X_train)):
        X_train[i] = to_categorical(X_train[i])
        X_val[i] = to_categorical(X_val[i])
        X_test[i] = to_categorical(X_test[i])

y_val = df_val['Sales_norm']

# %%
if with_embed:
    model = get_embedings_NN(X_columns)
else:
    model = get_keras_LR(X_columns, hidden_units=16)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Store_input         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ DayOfWeek_input     │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Promo_input         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Year_input          │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Month_input         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Week_input          │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Day_input           │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ StoreType_input     │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Assortment_input    │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ CompetitionDistanc… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Promo2_input        │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ PromoInterval_input │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ trend_input         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Precipitationmm_in… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Mean_TemperatureC_… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ CloudCover_input    │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Events_input        │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Store_embedding     │ (None, 1, 2)      │      2,230 │ Store_input[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ DayOfWeek_embedding │ (None, 1, 2)      │         14 │ DayOfWeek_input[… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Promo_embedding     │ (None, 1, 5)      │         10 │ Promo_input[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Year_embedding      │ (None, 1, 2)      │          6 │ Year_input[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Month_embedding     │ (None, 1, 2)      │         24 │ Month_input[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Week_embedding      │ (None, 1, 2)      │        104 │ Week_input[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Day_embedding       │ (None, 1, 2)      │         62 │ Day_input[0][0]   │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ StoreType_embedding │ (None, 1, 3)      │         12 │ StoreType_input[… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Assortment_embeddi… │ (None, 1, 3)      │          9 │ Assortment_input… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ CompetitionDistanc… │ (None, 1, 5)      │      3,270 │ CompetitionDista… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Promo2_embedding    │ (None, 1, 3)      │          6 │ Promo2_input[0][… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ PromoInterval_embe… │ (None, 1, 2)      │          8 │ PromoInterval_in… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ trend_embedding     │ (None, 1, 2)      │        134 │ trend_input[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Precipitationmm_em… │ (None, 1, 2)      │         78 │ Precipitationmm_… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Mean_TemperatureC_… │ (None, 1, 2)      │         88 │ Mean_Temperature… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ CloudCover_embeddi… │ (None, 1, 2)      │         18 │ CloudCover_input… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Events_embedding    │ (None, 1, 2)      │         44 │ Events_input[0][… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Store_flatten       │ (None, 2)         │          0 │ Store_embedding[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ DayOfWeek_flatten   │ (None, 2)         │          0 │ DayOfWeek_embedd… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Promo_flatten       │ (None, 5)         │          0 │ Promo_embedding[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Year_flatten        │ (None, 2)         │          0 │ Year_embedding[0… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Month_flatten       │ (None, 2)         │          0 │ Month_embedding[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Week_flatten        │ (None, 2)         │          0 │ Week_embedding[0… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Day_flatten         │ (None, 2)         │          0 │ Day_embedding[0]… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ StoreType_flatten   │ (None, 3)         │          0 │ StoreType_embedd… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Assortment_flatten  │ (None, 3)         │          0 │ Assortment_embed… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ CompetitionDistanc… │ (None, 5)         │          0 │ CompetitionDista… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Promo2_flatten      │ (None, 3)         │          0 │ Promo2_embedding… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ PromoInterval_flat… │ (None, 2)         │          0 │ PromoInterval_em… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ trend_flatten       │ (None, 2)         │          0 │ trend_embedding[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Precipitationmm_fl… │ (None, 2)         │          0 │ Precipitationmm_… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Mean_TemperatureC_… │ (None, 2)         │          0 │ Mean_Temperature… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ CloudCover_flatten  │ (None, 2)         │          0 │ CloudCover_embed… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Events_flatten      │ (None, 2)         │          0 │ Events_embedding… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 43)        │          0 │ Store_flatten[0]… │
# │ (Concatenate)       │                   │            │ DayOfWeek_flatte… │
# │                     │                   │            │ Promo_flatten[0]… │
# │                     │                   │            │ Year_flatten[0][… │
# │                     │                   │            │ Month_flatten[0]… │
# │                     │                   │            │ Week_flatten[0][… │
# │                     │                   │            │ Day_flatten[0][0… │
# │                     │                   │            │ StoreType_flatte… │
# │                     │                   │            │ Assortment_flatt… │
# │                     │                   │            │ CompetitionDista… │
# │                     │                   │            │ Promo2_flatten[0… │
# │                     │                   │            │ PromoInterval_fl… │
# │                     │                   │            │ trend_flatten[0]… │
# │                     │                   │            │ Precipitationmm_… │
# │                     │                   │            │ Mean_Temperature… │
# │                     │                   │            │ CloudCover_flatt… │
# │                     │                   │            │ Events_flatten[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 32)        │      1,408 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         33 │ dense_4[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,558 (29.52 KB)
#  Trainable params: 7,558 (29.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 15
model.compile(optimizers.Adam(learning_rate=0.001), loss='mse', metrics=[rmspe, 'mse'])
cbs = [callbacks.ReduceLROnPlateau(monitor='val_rmspe', mode='min', verbose=1, patience=2), 
       callbacks.ModelCheckpoint('best_val_rmspe.keras', monitor='val_rmspe', mode='min', verbose=1, save_best_only=True),
       callbacks.EarlyStopping(monitor='val_rmspe', mode='min', patience=5, verbose=1, restore_best_weights=True)]
if final_train:
    model.fit(X_train, y_train, epochs=epochs, callbacks=cbs)
else:
    model.fit(X_train, y_train, epochs=epochs, validation_data=(X_val, y_val), callbacks=cbs)
# Out:
# Epoch 1/15
# C:\Users\pazar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['Store_input', 'DayOfWeek_input', 'Promo_input', 'Year_input', 'Month_input', 'Week_input', 'Day_input', 'StoreType_input', 'Assortment_input', 'CompetitionDistance_input', 'Promo2_input', 'PromoInterval_input', 'trend_input', 'Precipitationmm_input', 'Mean_TemperatureC_input', 'CloudCover_input', 'Events_input']. Received: the structure of inputs=('*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*')
#   warnings.warn(
# 25440/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - rmspe: 0.2128
# C:\Users\pazar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['Store_input', 'DayOfWeek_input', 'Promo_input', 'Year_input', 'Month_input', 'Week_input', 'Day_input', 'StoreType_input', 'Assortment_input', 'CompetitionDistance_input', 'Promo2_input', 'PromoInterval_input', 'trend_input', 'Precipitationmm_input', 'Mean_TemperatureC_input', 'CloudCover_input', 'Events_input']. Received: the structure of inputs=('*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*')
#   warnings.warn(
# Epoch 1: val_rmspe improved from inf to 0.16215, saving model to best_val_rmspe.keras
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 207s 7ms/step - loss: 0.0011 - mse: 0.0011 - rmspe: 0.2128 - val_loss: 7.0281e-04 - val_mse: 7.0281e-04 - val_rmspe: 0.1622 - learning_rate: 0.0010
# Epoch 2/15
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4171e-04 - mse: 5.4171e-04 - rmspe: 0.1480
# Epoch 2: val_rmspe improved from 0.16215 to 0.15168, saving model to best_val_rmspe.keras
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 208s 8ms/step - loss: 5.4171e-04 - mse: 5.4171e-04 - rmspe: 0.1480 - val_loss: 6.2852e-04 - val_mse: 6.2852e-04 - val_rmspe: 0.1517 - learning_rate: 0.0010
# Epoch 3/15
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0828e-04 - mse: 5.0828e-04 - rmspe: 0.1446
# Epoch 3: val_rmspe improved from 0.15168 to 0.15023, saving model to best_val_rmspe.keras
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 185s 7ms/step - loss: 5.0828e-04 - mse: 5.0828e-04 - rmspe: 0.1446 - val_loss: 6.2612e-04 - val_mse: 6.2612e-04 - val_rmspe: 0.1502 - learning_rate: 0.0010
# Epoch 4/15
# 25438/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9126e-04 - mse: 4.9126e-04 - rmspe: 0.1419
# Epoch 4: val_rmspe improved from 0.15023 to 0.14290, saving model to best_val_rmspe.keras
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 148s 6ms/step - loss: 4.9126e-04 - mse: 4.9126e-04 - rmspe: 0.1419 - val_loss: 5.9187e-04 - val_mse: 5.9187e-04 - val_rmspe: 0.1429 - learning_rate: 0.0010
# Epoch 5/15
# 25431/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8370e-04 - mse: 4.8370e-04 - rmspe: 0.1418
# Epoch 5: val_rmspe did not improve from 0.14290
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 145s 6ms/step - loss: 4.8371e-04 - mse: 4.8371e-04 - rmspe: 0.1418 - val_loss: 6.2706e-04 - val_mse: 6.2706e-04 - val_rmspe: 0.1554 - learning_rate: 0.0010
# Epoch 6/15
# 25439/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8338e-04 - mse: 4.8338e-04 - rmspe: 0.1404
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 6: val_rmspe did not improve from 0.14290
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 158s 6ms/step - loss: 4.8338e-04 - mse: 4.8338e-04 - rmspe: 0.1404 - val_loss: 5.8313e-04 - val_mse: 5.8313e-04 - val_rmspe: 0.1435 - learning_rate: 0.0010
# Epoch 7/15
# 25435/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4252e-04 - mse: 4.4252e-04 - rmspe: 0.1338
# Epoch 7: val_rmspe improved from 0.14290 to 0.13973, saving model to best_val_rmspe.keras
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 211s 8ms/step - loss: 4.4252e-04 - mse: 4.4252e-04 - rmspe: 0.1338 - val_loss: 6.1218e-04 - val_mse: 6.1218e-04 - val_rmspe: 0.1397 - learning_rate: 1.0000e-04
# Epoch 8/15
# 25442/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3139e-04 - mse: 4.3139e-04 - rmspe: 0.1319
# Epoch 8: val_rmspe did not improve from 0.13973
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 229s 9ms/step - loss: 4.3139e-04 - mse: 4.3139e-04 - rmspe: 0.1319 - val_loss: 6.0209e-04 - val_mse: 6.0209e-04 - val_rmspe: 0.1399 - learning_rate: 1.0000e-04
# Epoch 9/15
# 25440/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3183e-04 - mse: 4.3183e-04 - rmspe: 0.1330
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 9: val_rmspe did not improve from 0.13973
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 179s 7ms/step - loss: 4.3183e-04 - mse: 4.3183e-04 - rmspe: 0.1330 - val_loss: 6.4310e-04 - val_mse: 6.4310e-04 - val_rmspe: 0.1410 - learning_rate: 1.0000e-04
# Epoch 10/15
# 25440/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2621e-04 - mse: 4.2621e-04 - rmspe: 0.1307
# Epoch 10: val_rmspe did not improve from 0.13973
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 213s 7ms/step - loss: 4.2621e-04 - mse: 4.2621e-04 - rmspe: 0.1307 - val_loss: 6.2842e-04 - val_mse: 6.2842e-04 - val_rmspe: 0.1408 - learning_rate: 1.0000e-05
# Epoch 11/15
# 25438/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3013e-04 - mse: 4.3013e-04 - rmspe: 0.1309
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 11: val_rmspe did not improve from 0.13973
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 151s 6ms/step - loss: 4.3013e-04 - mse: 4.3013e-04 - rmspe: 0.1309 - val_loss: 6.2976e-04 - val_mse: 6.2976e-04 - val_rmspe: 0.1410 - learning_rate: 1.0000e-05
# Epoch 12/15
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2144e-04 - mse: 4.2144e-04 - rmspe: 0.1320
# Epoch 12: val_rmspe did not improve from 0.13973
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 101s 4ms/step - loss: 4.2144e-04 - mse: 4.2144e-04 - rmspe: 0.1320 - val_loss: 6.2999e-04 - val_mse: 6.2999e-04 - val_rmspe: 0.1409 - learning_rate: 1.0000e-06
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %%
model.load_weights('best_val_rmspe.keras')

# %% [markdown]
# ## Pruebas

# %%
model.evaluate(X_train, y_train)
# Out:
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 130s 5ms/step - loss: 4.4624e-04 - mse: 4.4624e-04 - rmspe: 0.1231
# [0.00043317567906342447, 0.127071350812912, 0.00043317567906342447]

# %%
model.evaluate(X_val, y_val)
# Out:
# 944/944 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 6.5090e-04 - mse: 6.5090e-04 - rmspe: 0.1340
# [0.0006121763726696372, 0.1397266834974289, 0.0006121763726696372]

# %%
from matplotlib import pyplot as plt

# %%
def plot_embed(layer_name, cat_names):
    Y = model.get_layer(layer_name).get_weights()[0]
    print(Y.shape)
    plt.figure(figsize=(8,8))
    plt.scatter(-Y[:, 0], -Y[:, 1])
    for i, txt in enumerate(cat_names):
        plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')

# %%
plot_embed('DayOfWeek_embedding', ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun'])
# Out:
# (7, 2)

# %%
plot_embed('Store_embedding', list(range(1115)))
# Out:
# (1115, 2)

# %% [raw]
# Store, DayOfWeek: 0.09212721139192581, 0.048540305346250534
# Store, DayOfWeek, Week: 0.0615, 0.02256705053150654
# Store, DayOfWeek, Week, Month: 0.061621, 0.02359057404100895

# %%
train_predictions = model.predict(X_train)*max_sales
get_metric(df_train['Sales'].values, train_predictions.reshape(-1))
# Out:
# C:\Users\pazar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['Store_input', 'DayOfWeek_input', 'Promo_input', 'Year_input', 'Month_input', 'Week_input', 'Day_input', 'StoreType_input', 'Assortment_input', 'CompetitionDistance_input', 'Promo2_input', 'PromoInterval_input', 'trend_input', 'Precipitationmm_input', 'Mean_TemperatureC_input', 'CloudCover_input', 'Events_input']. Received: the structure of inputs=('*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*')
#   warnings.warn(
# 25443/25443 ━━━━━━━━━━━━━━━━━━━━ 170s 6ms/step
# 0.19812636341560486

# %% [markdown]
# ## Prediccion

# %%
test_predictions = model.predict(X_test)*max_sales
test_predictions[df_test['Open'] == 0] = 0
# Out:
# 1284/1284 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step

# %%
sample_csv = pd.read_csv('rossmann/sample_submission.csv')
sample_csv['Sales'] = test_predictions
sample_csv.head()

sample_csv.to_csv(f'submision_Arribere_Davila_4.csv', index=False)
